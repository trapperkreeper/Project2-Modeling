# %%
import pandas as pd

# %%
tuning = ['Baseline', 'VIF', 'Undersampling', 'Grid Search CV']
precision = [0.55, 0.52, 0.29, 0.29]
recall = [0.17, 0.12, 0.79, 0.81]

df = pd.DataFrame({
    'Tuning': tuning,
    'Precision': precision,
    'Recall': recall
})

df.plot.line(x='Tuning', ylim=(0,1))
# Out:
# <Axes: xlabel='Tuning'>
